# %%
import requests as req 
from bs4 import BeautifulSoup
import pandas as pd
import json
import re
import numpy as np
# from pprint im

# %%
Cat= pd.read_csv('Cat CSVs/Cat_cleanup1.csv')
Cat1= pd.read_csv('Cat CSVs/Cat_cleanup2.csv')
Cat2= pd.read_csv('Cat CSVs/Cat_cleanup3.csv')
Cat3= pd.read_csv('Cat CSVs/Cat_cleanup4.csv')

# %%
Cat.head()
# Out:
#                      Raza
# 0                Abisinio  \
# 1  Americano de pelo duro
# 2                Asiático
# 3               Azul ruso
# 4                 Balinés
#
#                                                                                                                                  Foto
# 0    https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0000_Abyssinian.jpg?itok=YY33eNJ5  \
# 1   https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/breed_library/cat_american_wirehair.jpg?itok=SejyBh34
# 2               https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/breed_library/cat_asian.jpg?itok=BWqTeK9g
# 3  https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0020_Russian_blue.jpg?itok=BXQUKAJd
# 4      https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0001_Balinese.jpg?itok=t43srJl2
#
# ...

# %%
Cat1.head()
# Out:
#                       Raza
# 0  Británico de pelo corto  \
# 1                   Burmés
# 2                 Burmilla
# 3               Chinchilla
# 4              Cornish rex
#
#                                                                                                                                       Foto
# 0  https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0004_British_shorthair.jpg?itok=JwO9XrA5  \
# 1            https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0005_Burmese.jpg?itok=qRRzSTcr
# 2           https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0006_Burmilla.jpg?itok=sdfktGDJ
# 3               https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/breed_library/cat_chinchilla.jpg?itok=UhSoF3rT
# ...

# %%
Cat2.head()
# Out:
#                Raza
# 0        Maine coon  \
# 1              Manx
# 2       Mau egipcio
# 3  Mist australiano
# 4          Munchkin
#
#                                                                                                                                  Foto
# 0    https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0012_Maine_coon.jpg?itok=rW5yQdJM  \
# 1                https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/breed_library/cat_manx.jpg?itok=mIOFl0io
# 2  https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0009_Egyptian_mau.jpg?itok=yFkMvDSS
# 3     https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/breed_library/cat_australian_mist.jpg?itok=A57IM_ll
# 4            https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/breed_library/cat_munchkin.jpg?itok=MwSfUIeu
#
# ...

# %%
Cat3.head()
# Out:
#           Raza
# 0  Selkirk rex  \
# 1       Siamés
# 2    Singapura
# 3     Snowshoe
# 4       Somalí
#
#                                                                                                                                 Foto
# 0  https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0022_Selkirk_rex.jpg?itok=buQUG9Zc  \
# 1      https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0023_Siamese.jpg?itok=qxKnKrba
# 2          https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/breed_library/cat_singapura.jpg?itok=zp5CZnjJ
# 3     https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0024_Snowshoe.jpg?itok=oiuYSv8V
# 4       https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0025_Somali.jpg?itok=u-_NibBO
#
# ...

# %%
Allcats= pd.concat([Cat, Cat1, Cat2, Cat3], ignore_index=True)
Allcats['Origen']= Allcats['Origen'].str.replace('EE. UU.' , 'Estados Unidos')

Allcats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Raza         45 non-null     object
#  1   Foto         45 non-null     object
#  2   Origen       42 non-null     object
#  3   Descripción  45 non-null     object
#  4   Rasgo 1      45 non-null     object
#  5   Rasgo 2      45 non-null     object
#  6   Rasgo 3      45 non-null     object
#  7   Rasgo 4      45 non-null     object
#  8   Rasgo 5      45 non-null     object
#  9   Rasgo 6      45 non-null     object
#  10  Rasgo 7      45 non-null     object
#  11  Rasgo 8      45 non-null     object
# dtypes: object(12)
# memory usage: 4.3+ KB

# %%
Allcats.head()
# Out:
#                      Raza
# 0                Abisinio  \
# 1  Americano de pelo duro
# 2                Asiático
# 3               Azul ruso
# 4                 Balinés
#
#                                                                                                                                  Foto
# 0    https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0000_Abyssinian.jpg?itok=YY33eNJ5  \
# 1   https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/breed_library/cat_american_wirehair.jpg?itok=SejyBh34
# 2               https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/breed_library/cat_asian.jpg?itok=BWqTeK9g
# 3  https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0020_Russian_blue.jpg?itok=BXQUKAJd
# 4      https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0001_Balinese.jpg?itok=t43srJl2
#
# ...

# %%
import pandas as pd

# Split the string at the first occurrence of "."
split_data = Allcats['Origen'].str.split('.', n=1, expand=True)

# Assign the split values to the respective columns
Allcats['Origen'] = split_data[1].str.strip()
Allcats['País'] = split_data[0].replace('País de origen:', '', regex=True).str.strip()


Allcats
# Out:
#                              Raza
# 0                        Abisinio  \
# 1          Americano de pelo duro
# 2                        Asiático
# 3                       Azul ruso
# 4                         Balinés
# 5                         Bengalí
# 6                         Birmano
# 7   Bobtail japonés de pelo corto
# 8   Bobtail japonés de pelo largo
# 9                          Bombay
# 10              Bosque de Noruega
# 11              Bosque de Siberia
# 12        Británico de pelo corto
# 13                         Burmés
# 14                       Burmilla
# 15                     Chinchilla
# 16                    Cornish rex
# 17                         Cymric
# 18                      Devon Rex
# 19          Exótico de pelo corto
# 20                   Fold escocés
# 21                     Khao Manee
# 22                          Korat
# 23                         Laperm
# 24                     Maine coon
# 25                           Manx
# ...

# %%
Allcats.loc[27, 'Origen'] = 'El mist australiano es una raza de pelo corto creada en Australia en 1970 por el cruce de burmeses, abisinios y gatos domésticos de pelo corto con el fin de crear un gato de pelaje moteado, por eso se le denominó inicialmente mist moteado. A medida que la raza se fue desarrollando y aparecieron más patrones, como los pelajes marmolados, surgió la necesidad de modificar el nombre, que se cambió en 1998 por el de mist australiano. No hay muchos mist australianos en el Reino Unido y en Europa, pero la raza está aumentando y los criadores trabajan para que sea reconocida por las organizaciones de amigos de los gatos.'
Allcats.loc[33, 'Origen'] = 'El pixie bob apareció en los EE. UU. en 1980 a partir de gatos de granero de aspecto salvaje y otros gatos que recordaban un cruce entre un bobcat norteamericano y un gato doméstico. El nombre de la raza procede del gato que originó el desarrollo de la raza: Pixie. La raza llegó a Europa en 2001, pero no es muy común.'
Allcats.loc[42, 'Origen'] = 'El tiffanie es el único miembro del grupo asiático que tiene el pelo semilargo. Aparte del burmilla, que se originó por el cruce accidental entre un macho chinchilla y una hembra burmesa lila, los gatos del grupo asiático son obra de criadores que intentaban crear gatos de tipo burmés, pero en colores no habituales de esa raza. Durante el programa de cría de los asiáticos, en algunas camadas nacieron gatitos de pelaje largo que se usaron para crear esta raza tan bonita.'

Allcats.loc[27, 'País'] = 'Australia'
Allcats.loc[33, 'País'] = 'Estados Unidos'
Allcats.loc[42, 'País'] = 'Gran Bretaña'

Allcats.loc[42]
# Out:
# Raza                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Tiffanie
# Foto                                                                                                                                                                                                                                                                                                                                                                             https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/breed_library/cat_tiffanie.jpg?itok=LDAn31K6
# ...

# %%
column_name = Allcats.columns[11]  # Get the name of the column at position 11
column_index = 2  # Specify the new position for the column

columns = Allcats.columns.tolist()  # Get a list of all column names
columns.remove(column_name)  # Remove the column from its original position
columns.insert(column_index, column_name)  # Insert the column at the new position

Allcats = Allcats.reindex(columns=columns)  # Reindex the DataFrame with the updated column positions

# %%
Allcats
# Out:
#                              Raza
# 0                        Abisinio  \
# 1          Americano de pelo duro
# 2                        Asiático
# 3                       Azul ruso
# 4                         Balinés
# 5                         Bengalí
# 6                         Birmano
# 7   Bobtail japonés de pelo corto
# 8   Bobtail japonés de pelo largo
# 9                          Bombay
# 10              Bosque de Noruega
# 11              Bosque de Siberia
# 12        Británico de pelo corto
# 13                         Burmés
# 14                       Burmilla
# 15                     Chinchilla
# 16                    Cornish rex
# 17                         Cymric
# 18                      Devon Rex
# 19          Exótico de pelo corto
# 20                   Fold escocés
# 21                     Khao Manee
# 22                          Korat
# 23                         Laperm
# 24                     Maine coon
# 25                           Manx
# ...

# %%
print (Allcats['Rasgo 1'].value_counts(), '\n',
Allcats['Rasgo 2'].value_counts(), '\n',
Allcats['Rasgo 3'].value_counts(), '\n',
Allcats['Rasgo 4'].value_counts(), '\n',
Allcats['Rasgo 5'].value_counts(), '\n',
Allcats['Rasgo 6'].value_counts(), '\n',
Allcats['Rasgo 7'].value_counts(), '\n',
Allcats['Rasgo 8'].value_counts(), '\n'
)
# Out:
# Rasgo 1
# Gato curioso y juguetón      20
# Gato muy curioso y activo    18
# Gato tranquilo                7
# Name: count, dtype: int64
#  Rasgo 2
# Gato sociable y dependiente           17
# Gato amigable pero independiente      15
# 'Gato sociable y dependiente'         10
# 'Gato amigable pero independiente'     2
# Gato independiente                     1
# Name: count, dtype: int64
#  Rasgo 3
# Un gato silencioso     19
# Gato algo maullador    14
# Gato muy maullador     12
# Name: count, dtype: int64
#  Rasgo 4
# Raza de gato esbelta y elegante       19
# Raza de gato de constitución media    14
# Raza de gato más grande y robusta     12
# Name: count, dtype: int64
#  Rasgo 5
# Requiere aseo una vez por semana    27
# Requiere aseo todos los días        18
# Name: count, dtype: int64
#  Rasgo 6
# Raza alergénica        40
# Raza hipoalergénica     5
# Name: count, dtype: int64
#  Rasgo 7
# Necesita algo de espacio al aire libre    34
# ...

# %%
Allcats['Rasgo 2'] = Allcats['Rasgo 2'].replace({"'Gato sociable y dependiente'": 'Gato sociable y dependiente', "'Gato amigable pero independiente'" : 'Gato amigable pero independiente'})

# %%
Allcats['Rasgo 2'].value_counts()
# Out:
# Rasgo 2
# Gato sociable y dependiente         27
# Gato amigable pero independiente    17
# Gato independiente                   1
# Name: count, dtype: int64

# %%
pd.set_option('display.max_colwidth', None)
GatoAlérgico = Allcats.loc[Allcats['Rasgo 6']== 'Raza hipoalergénica']
GatoAlérgico
# Out:
#                  Raza
# 4             Balinés  \
# 11  Bosque de Siberia
# 16        Cornish rex
# 18          Devon Rex
# 41             Sphynx
#
#                                                                                                                                  Foto
# 4      https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0001_Balinese.jpg?itok=t43srJl2  \
# 11    https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/breed_library/cat_siberian_forest.jpg?itok=qnN8ERgr
# 16  https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0007_Cornish_rex.jpg?itok=WG4pjg4U
# 18    https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0008_Devon_rex.jpg?itok=woM4LN7C
# 41       https://purina.es/sites/default/files/styles/nppe_breed_selector_500/public/2021-02/CAT%20HERO_0026_Sphynx.jpg?itok=J4izQv9W
#
# ...

# %%
Allcats = Allcats.rename(columns={'Rasgo 1': 'Actividad', 'Rasgo 2': 'Sociabilidad', 'Rasgo 3' : 'Maullido', 'Rasgo 4' : 'Constitución', 'Rasgo 5' : 'Aseo', 'Rasgo 6': 'Alergia', 'Rasgo 7' : 'Espacio', 'Rasgo 8': 'Niños'})

# %%
Allcats.to_csv('Tablagatuna.csv', index=False)
