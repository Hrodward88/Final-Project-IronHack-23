# %%
import requests as req 
from bs4 import BeautifulSoup
import pandas as pd
import json
import re
# from pprint im

# %%
S_url= 'https://www.royalcanin.com/es/dogs/breeds/breed-library?sizes=961906a9-9054-4e7a-82a4-aa0e6c076897&filter=dcac5bcc-83a0-4a96-93fe-7ae986867f1b&viewAll=true'

# %%
S_html = req.get(S_url).content

# %%
S_soup = BeautifulSoup(S_html, 'html.parser')
S_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es-ES">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compa1tible"/>
# <meta content="telephone=no" name="format-detection">
# <meta content="96b557fabcadc264cfd487e112b0ce92b98b1199" name="naver-site-verification">
# <link href="https://dl.royalcanin.com" rel="preconnect"/>
# <link crossorigin="" href="https://www.googletagmanager.com" rel="preconnect">
# <link href="https://dl.royalcanin.com" rel="dns-prefetch"/>
# <link href="https://www.googletagmanager.com" rel="dns-prefetch">
# <link href="//cdn.cookielaw.org" rel="preconnect"/>
# <link href="//cdn.cookielaw.org" rel="dns-prefetch"/>
# ...

# %%
S_dogs = S_soup.find_all('h3')

S_name_list= []

for tag in S_dogs: 
   S_name_list.append(tag.text)

S_name_list= S_name_list[:-1]
S_name_list
# Out:
# ['Affenpinscher',
#  'Basset leonado de Bretaña',
#  'Bedlington terrier',
#  'Bichón Frisé',
#  'Bichón habanero',
#  'Border terrier',
#  'Boston terrier',
#  'Braco de Auvernia',
#  'Bull terrier',
#  'Cairn Terrier',
#  'Carlino',
#  'Cavalier King Charles',
#  'Coton de Tuléar',
#  'Dandie Dinmont Terrier',
#  'Fox terrier de pelo duro',
#  'Fox Terrier de Pelo Liso',
#  'Grifón Belga',
#  'Grifón de Bruselas',
#  'Jack Russell Terrier',
#  'Jagd Terrier',
#  'King Charles spaniel',
#  'Lakeland Terrier',
#  'Lhasa Apso',
#  'Lundehund noruego',
#  'Mudi',
#  'Parson Russell Terrier',
#  'Pastor de los Pirineos',
#  'Pastor de los Pirineos de Cara Rasa',
#  'Pastor de Shetland',
#  'Pekinés',
#  'Pequeño lebrel italiano',
#  'Pequeño perro león',
#  'Perro de Granja Danés y Sueco',
#  'Pinscher miniatura',
#  'Podenco portugués',
#  'Pumi',
#  'Ratonero Holandés',
#  'Schipperke',
#  'Schnauzer miniatura',
#  'Shiba inu',
#  'Shih tzu',
#  'Skye terrier',
#  'Spaniel tibetano',
# ...

# %%
div_tags = S_soup.find_all('div', {'class': 'rc-column'})

S_url_list = []

for div_tag in div_tags:
    a_tags = div_tag.find_all('a', {'class': 'rc-card__link rc-full-width', 'href': True})
    for a_tag in a_tags:
        href = a_tag.get('href')
        S_url_list.append(href)

S_url_list
# Out:
# ['https://www.royalcanin.com/es/dogs/breeds/breed-library/affenpinscher',
#  'https://www.royalcanin.com/es/dogs/breeds/breed-library/basset-fauve-de-bretagne',
#  'https://www.royalcanin.com/es/dogs/breeds/breed-library/bedlington-terrier',
#  'https://www.royalcanin.com/es/dogs/breeds/breed-library/bichon-frise',
#  'https://www.royalcanin.com/es/dogs/breeds/breed-library/havanese',
#  'https://www.royalcanin.com/es/dogs/breeds/breed-library/border-terrier',
#  'https://www.royalcanin.com/es/dogs/breeds/breed-library/boston-terrier',
#  'https://www.royalcanin.com/es/dogs/breeds/breed-library/auvergne-pointer',
#  'https://www.royalcanin.com/es/dogs/breeds/breed-library/bull-terrier',
#  'https://www.royalcanin.com/es/dogs/breeds/breed-library/cairn-terrier',
#  'https://www.royalcanin.com/es/dogs/breeds/breed-library/pug',
#  'https://www.royalcanin.com/es/dogs/breeds/breed-library/cavalier-king-charles-spaniel',
# ...

# %%
image_tags = S_soup.find_all('img')

image_urls = []

for img_tag in image_tags:
    if 'data-srcset' in img_tag.attrs:
        srcset = img_tag['data-srcset']
        urls = srcset.split(',')
        for url in urls:
            url = url.strip().split(' ')[0]
            if 'w=320' in url and 'nutrition' not in url and 'library' not in url:
                image_urls.append(url)

image_urls
# Out:
# ['https://cdn.royalcanin-weshare-online.io/CyLTxWoBaxEApS7L0xy3/v1/bd121bl-hub-affenpinscher-adult-standing?w=320&fm=jpg&auto=compress',
#  'https://cdn.royalcanin-weshare-online.io/AiLQxWoBaxEApS7L7Bxa/v1/bd138bl-hub-basset-fauve-de-bretagne-adult-standing?w=320&fm=jpg&auto=compress',
#  'https://cdn.royalcanin-weshare-online.io/DCLUxWoBaxEApS7LIRwL/v3/bd143bl-hub-bedlington-terrier-adult-standing?w=320&fm=jpg&auto=compress',
#  'https://cdn.royalcanin-weshare-online.io/4GlFHWsBG95Xk-RB8fhT/v1/bd31bl-hub-bichon-frise-adult-standing?w=320&fm=jpg&auto=compress',
#  'https://cdn.royalcanin-weshare-online.io/MyLgHWsBaxEApS7LnR1b/v1/bd72bl-hub-havanese-adult-standing?w=320&fm=jpg&auto=compress',
#  'https://cdn.royalcanin-weshare-online.io/6GlPHWsBG95Xk-RBdPjR/v1/bd35bl-hub-border-terrier-adult-standing?w=320&fm=jpg&auto=compress',
#  'https://cdn.royalcanin-weshare-online.io/62lSHWsBG95Xk-RBcPhv/v1/bd37bl-hub-boston-terrier-adult-standing?w=320&fm=jpg&auto=compress',
# ...

# %%
import requests
from bs4 import BeautifulSoup

div_tags = S_soup.find_all('div', {'class': 'rc-column'})

href_list = []
div_list = []

for div_tag in div_tags:
    a_tags = div_tag.find_all('a', {'class': 'rc-card__link rc-full-width', 'href': True})
    for a_tag in a_tags:
        href = a_tag.get('href')
        
        # Scrape the corresponding <div class="rc-column">
        response = requests.get(href)
        soup = BeautifulSoup(response.content, 'html.parser')
        target_div = soup.find('div', {'class': 'rc-padding--sm rc-margin-bottom--xs rc-bg-colour--brand3'})
        
        # Process the scraped <div> element as needed
        if target_div:
            div_elements = target_div.find_all('div', {'class': 'rc-column'})
            div_texts = [div.text.strip() for div in div_elements]
            
            href_list.append(href)
            div_list.append(div_texts)
        else:
            href_list.append(href)
            div_list.append(None)

# Print the scraped data
print(href_list)
print(div_list)
# Out:
# ['https://www.royalcanin.com/es/dogs/breeds/breed-library/affenpinscher', 'https://www.royalcanin.com/es/dogs/breeds/breed-library/basset-fauve-de-bretagne', 'https://www.royalcanin.com/es/dogs/breeds/breed-library/bedlington-terrier', 'https://www.royalcanin.com/es/dogs/breeds/breed-library/bichon-frise', 'https://www.royalcanin.com/es/dogs/breeds/breed-library/havanese', 'https://www.royalcanin.com/es/dogs/breeds/breed-library/border-terrier', 'https://www.royalcanin.com/es/dogs/breeds/breed-library/boston-terrier', 'https://www.royalcanin.com/es/dogs/breeds/breed-library/auvergne-pointer', 'https://www.royalcanin.com/es/dogs/breeds/breed-library/bull-terrier', 'https://www.royalcanin.com/es/dogs/breeds/breed-library/cairn-terrier', 'https://www.royalcanin.com/es/dogs/breeds/breed-library/pug', 'https://www.royalcanin.com/es/dogs/breeds/breed-library/cavalier-king-charles-spaniel', 'https://www.royalcanin.com/es/dogs/breeds/breed-library/coton-de-tulear', 'https://www.royalcanin.co
# ...

# %%
pd.set_option('display.max_colwidth', None)

S_Dogsdf= pd.DataFrame(div_list)
S_Dogsdf
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0
# ...

# %%
S_Dogsdf[2]
# Out:
# 0                              Información clave\n\n\nUn gran perro para una familia\n\n\nRequiere muchos cuidados\n\n\nJardín no esencial
# 1                                                        Información clave\n\n\nRequiere espacio exterior\n\n\nNecesita cuidados moderados
# 2                   Información clave\n\n\nNecesita cuidados moderados\n\n\nDisfruta del entrenamiento\n\n\nUn gran perro para una familia
# 3                          Información clave\n\n\nRequiere muchos cuidados\n\n\nJardín no esencial\n\n\nNecesita un entrenamiento moderado
# 4                          Información clave\n\n\nUn gran perro guardián\n\n\nNecesita poco entrenamiento\n\n\nNecesita cuidados moderados
# 5                              Información clave\n\n\nNecesita cuidados moderados\n\n\nJardín no esencial\n\n\nNecesita poco entrenamiento
# 6                              Información clave\n\n\nNecesita cuidados moderados\n\n\nJardín no esencial\n\n\nNecesita poco entrenamiento
# ...

# %%
pd.set_option('display.max_colwidth', None)


# Replace all occurrences of \n with a space in the first column


# Assuming you have the DataFrame S_Dogsdf and you want to modify the first column (column index 0)
S_Dogsdf.iloc[:, 2] = S_Dogsdf.iloc[:, 2].str.replace('Información clave', '')
# Replace "\n\n\n" with a line change
S_Dogsdf.iloc[:, 2] = S_Dogsdf.iloc[:, 2].str.replace('\n\n\n', '\n')
S_Dogsdf.iloc[:, 2] = S_Dogsdf.iloc[:, 2].str.replace('\n', ' - ')

S_Dogsdf
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0
# ...

# %%
S_Dogsdf[2]
# Out:
# 0                               - Un gran perro para una familia - Requiere muchos cuidados - Jardín no esencial
# 1                                                      - Requiere espacio exterior - Necesita cuidados moderados
# 2                    - Necesita cuidados moderados - Disfruta del entrenamiento - Un gran perro para una familia
# 3                           - Requiere muchos cuidados - Jardín no esencial - Necesita un entrenamiento moderado
# 4                           - Un gran perro guardián - Necesita poco entrenamiento - Necesita cuidados moderados
# 5                               - Necesita cuidados moderados - Jardín no esencial - Necesita poco entrenamiento
# 6                               - Necesita cuidados moderados - Jardín no esencial - Necesita poco entrenamiento
# 7             - Un gran perro para una familia - Paciente con niños y otros animales - Requiere cuidados mínimos
# ...

# %%
pd.set_option('display.max_colwidth', None)

S_Dogsdf.iloc[:, 1] = S_Dogsdf.iloc[:, 1].str.replace('Especificidades de la raza\n\n', '')
S_Dogsdf.iloc[:, 1] = S_Dogsdf.iloc[:, 1].str.replace('\n\n', ' Personalidad: ')
S_Dogsdf.iloc[:, 1] = S_Dogsdf.iloc[:, 1].str.replace('País\n', 'País: ')
S_Dogsdf.iloc[:, 1] = S_Dogsdf.iloc[:, 1].str.replace('Categoría de tamaño\n', 'Categoría de tamaño: ')
S_Dogsdf.iloc[:, 1] = S_Dogsdf.iloc[:, 1].str.replace('Esperanza de vida promedio\n', 'Esperanza de vida promedio: ')
S_Dogsdf.iloc[:, 1] = S_Dogsdf.iloc[:, 1].str.replace('\n', ' ')

S_Dogsdf
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0
# ...

# %%
S_Dogsdf.iloc[:, 0] = S_Dogsdf.iloc[:, 0].str.split('\n', n=1).str[1]
S_Dogsdf.iloc[:, 0] = S_Dogsdf.iloc[:, 0].str.replace('\n', ' ')
S_Dogsdf
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0
# ...

# %%
S_Dogsdf.rename(columns= {0: 'Acerca de', 1 : 'Especificidades de la raza', 2 : 'Información clave'}, inplace=True)

S_Dogsdf
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Acerca de
# ...

# %%
S_Dogsdf['Raza']= S_name_list
S_Dogsdf['Tamaño']= 'S (5-10 kg)'
S_Dogsdf['Foto'] = image_urls

S_Dogsdf = S_Dogsdf[['Raza', 'Foto', 'Acerca de', 'Especificidades de la raza', 'Información clave', 'Tamaño']]
S_Dogsdf
# Out:
#                                    Raza
# 0                         Affenpinscher  \
# 1             Basset leonado de Bretaña
# 2                    Bedlington terrier
# 3                          Bichón Frisé
# 4                       Bichón habanero
# 5                        Border terrier
# 6                        Boston terrier
# 7                     Braco de Auvernia
# 8                          Bull terrier
# 9                         Cairn Terrier
# 10                              Carlino
# 11                Cavalier King Charles
# 12                      Coton de Tuléar
# 13               Dandie Dinmont Terrier
# 14             Fox terrier de pelo duro
# 15             Fox Terrier de Pelo Liso
# 16                         Grifón Belga
# 17                   Grifón de Bruselas
# 18                 Jack Russell Terrier
# 19                         Jagd Terrier
# 20                 King Charles spaniel
# 21                     Lakeland Terrier
# ...

# %%
new_values = ['País: Alemania Categoría de tamaño: Pequeño Esperanza de vida promedio: 12–14 años Personalidad: Seguro / Alerta / Leal / Entusiasta / Equilibrado', 
              'País: Estados Unidos Categoría de tamaño: Pequeño Esperanza de vida promedio: 13–15 años Personalidad: Afable / Alegre / Inteligente / Equilibrado', 
              'País: Reino Unido Categoría de tamaño: Pequeño Esperanza de vida promedio: 10–14 años Personalidad: Alegre / Cariñoso / Seguro / Afable / Equilibrado',
              'País: Bélgica Categoría de tamaño: Pequeño Esperanza de vida promedio: 12–15 años Personalidad: Inteligente / Equilibrado / Alerta / Fuerte / Leal / Seguro',
              'País: Reino Unido Categoría de tamaño: Pequeño Esperanza de vida promedio: 10–12 años Personalidad: Afable / Inteligente / Tímido / Dócil / Cariñoso',
              'País: Tíbet Categoría de tamaño: Pequeño Esperanza de vida promedio: 12–15 años Personalidad: Afable / Seguro / Alerta / Equilibrado / Tímido',
              'País: Alemania Categoría de tamaño: Pequeño Esperanza de vida promedio: 12–15 años Personalidad: Obstinado / Inteligente / Seguro / Alerta / Equilibrado',
              'País: Tibét Categoría de tamaño: Pequeño Esperanza de vida promedio: 12–15 años Personalidad: Alegre / Alerta / Equilibrado / Afable / Seguro / Inteligente / Tímido / Leal / Independiente',
              'País: Escocia Categoría de tamaño: Pequeño Esperanza de vida promedio: 12–14 años Personalidad: Alegre / Juguetón / Fuerte / Seguro / Alerta / Afable / Independiente']
# Replace the content in row 10 of the 'Especificidades de la raza' column
S_Dogsdf.loc[0, 'Especificidades de la raza'] = new_values[0]
S_Dogsdf.loc[6, 'Especificidades de la raza'] = new_values[1]
S_Dogsdf.loc[11, 'Especificidades de la raza'] = new_values[2]
S_Dogsdf.loc[17, 'Especificidades de la raza'] = new_values[3]
S_Dogsdf.loc[20, 'Especificidades de la raza'] = new_values[4]
S_Dogsdf.loc[22, 'Especificidades de la raza'] = new_values[5]
S_Dogsdf.loc[38, 'Especificidades de la raza'] = new_values[6]
S_Dogsdf.loc[42, 'Especificidades de la raza'] = new_values[7]
S_Dogsdf.loc[57, 'Especificidades de la raza'] = new_values[8]

S_Dogsdf
# Out:
#                                    Raza
# 0                         Affenpinscher  \
# 1             Basset leonado de Bretaña
# 2                    Bedlington terrier
# 3                          Bichón Frisé
# 4                       Bichón habanero
# 5                        Border terrier
# 6                        Boston terrier
# 7                     Braco de Auvernia
# 8                          Bull terrier
# 9                         Cairn Terrier
# 10                              Carlino
# 11                Cavalier King Charles
# 12                      Coton de Tuléar
# 13               Dandie Dinmont Terrier
# 14             Fox terrier de pelo duro
# 15             Fox Terrier de Pelo Liso
# 16                         Grifón Belga
# 17                   Grifón de Bruselas
# 18                 Jack Russell Terrier
# 19                         Jagd Terrier
# 20                 King Charles spaniel
# 21                     Lakeland Terrier
# ...

# %%
S_Dogsdf.to_csv('S.csv', index= False)
