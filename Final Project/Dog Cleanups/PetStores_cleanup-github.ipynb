# %%
import requests as req 
from bs4 import BeautifulSoup
import pandas as pd
import json
import re
# from pprint im

# %%
#pip install googlemaps
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import googlemaps

# Replace 'YOUR_API_KEY' with your actual API key
api_key = '-'
gmaps = googlemaps.Client(key=api_key)
YOUR_API_KEY = '-'

# %%
#This is to get an input from the user




# Initialize the Google Maps Geocoding client
gmaps = googlemaps.Client(api_key='AIzaSyDpY4rSYCn3_B59-hxMT9cesG0O7cSkUnM')

# Prompt the user to enter an address
address = input("Enter an address: ")

# Use the Geocoding API to retrieve the latitude and longitude of the address
geocode_result = gmaps.geocode(address)

# Extract the latitude and longitude from the geocode result
if geocode_result:
    location = geocode_result[0]['geometry']['location']
    latitude = location['lat']
    longitude = location['lng']
    print(f"Latitude: {latitude}")
    print(f"Longitude: {longitude}")
else:
    print("Unable to geocode the address.")

#This is to find something in a radius from a point


'''# Specify the location and radius of the region you want to search in
location = '40.4016635,-3.6962508'  # Latitude and longitude of the center point
radius = 1000  # Radius in meters

# Perform the nearby search
response = gmaps.places_nearby(
    location=location,
    radius=radius,
    keyword='dog shops',  # Your specific keyword for the type of shops you're interested in
)
'''

response = gmaps.places_nearby(
    location=(latitude, longitude),
    radius=1000,
    keyword='dog shops',
)

shops = response['results']

for shop in shops:
    name = shop['name']
    address = shop['vicinity']
    # Extract any other relevant details you need

    print(f"Name: {name}")
    print(f"Address: {address}")
    print('---')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[169], line 7
#       1 #This is to get an input from the user
#       2
#       3
#       4
#       5
#       6 # Initialize the Google Maps Geocoding client
# ----> 7 gmaps = googlemaps.Client(api_key='AIzaSyDpY4rSYCn3_B59-hxMT9cesG0O7cSkUnM')
#       9 # Prompt the user to enter an address
#      10 address = input("Enter an address: ")
#
# TypeError: Client.__init__() got an unexpected keyword argument 'api_key'

# %%
import googlemaps

# Prompt the user to enter an address
address = input("Enter an address: ")

# Initialize the Google Maps Geocoding client with your API key
gmaps = googlemaps.Client(key=YOUR_API_KEY)

# Use the Geocoding API to retrieve the latitude and longitude of the address
geocode_result = gmaps.geocode(address)

# Extract the latitude and longitude from the geocode result
if geocode_result:
    location = geocode_result[0]['geometry']['location']
    latitude = location['lat']
    longitude = location['lng']
    print(f"Latitude: {latitude}")
    print(f"Longitude: {longitude}")
else:
    print("No se ha podido usar geocode con esta dirección.")


groups = [
    {
        'group_name': 'PROTECTORAS DE ANIMALES',
        'keyword': 'protectora animales, animal shelter',
        'radius_prompt' : "Radio de búsqueda en metros para protectoras: "
    },
    {
        'group_name': 'VETERINARIOS',
        'keyword': 'Veterinario, Veterinary',
        'radius_prompt' : "Radio de búsqueda en metros para veterinarios: "
    },
    {
        'group_name': 'TIENDAS DE MASCOTAS',
        'keyword': 'Tiendas de mascotas, pet shop, animal shop, tienda de animales',
        'radius_prompt' : "Radio de búsqueda en metros para tiendas de mascotas: "
    },
    {
        'group_name': 'CRIADORES DE PERROS',
        'keyword': 'Criadores, criadores de perros, dog breeders, kennels, cat breeders, criadores de gatos',
        'radius_prompt' : "Radio de búsqueda en metros para criadores: "
    }
]

for group in groups:
    group_name = group['group_name']
    keyword = group['keyword']
    radius_prompt = group['radius_prompt']

    radius = input(radius_prompt)

    # Perform the nearby search for dog shops
    response = gmaps.places_nearby(
        location=(latitude, longitude),
        radius= int(radius),
        keyword=keyword 
    )

    shops = response['results']
    
    if shops:
        print("\n", 
              f"RESULTS FOR {group_name} (Range: {radius} m): ", 
              "\n", 
              "\n")
        for shop in shops:
            name = shop['name']
            address = shop['vicinity']
            opening_hours = shop.get('opening_hours', {})
            is_open_now = opening_hours.get('open_now', False)
            current_opening_hours = opening_hours.get('periods', [])
            website = shop.get('website', 'No disponible')
            phone_number = shop.get('formatted_phone_number', 'No disponible')

             # Calculate the distance between the location and the shop
            shop_location = shop['geometry']['location']
            shop_latitude = shop_location['lat']
            shop_longitude = shop_location['lng']
            distance = gmaps.distance_matrix(
                origins=(latitude, longitude),
                destinations=(shop_latitude, shop_longitude),
                mode='walking'
            )['rows'][0]['elements'][0]['distance']['text']

            print(f"Nombre: {name}")
            print(f"Dirección: {address}")
            print(f"Distancia: {distance}")
            if is_open_now:
                print("Actualmente: Abierto")
            else:
                print("Actualmente: Cerrado")
            
            if current_opening_hours:
                print("Horario:")
                for period in current_opening_hours:
                    day = period['open']['day']
                    start_time = period['open']['time']
                    end_time = period['close']['time']
                    day_name = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friiday', 'Saturday', 'Sunday'][day]
                    print(f"Day: {day}, Start Time: {start_time}, End Time: {end_time}")
            else:
                print("Horario no disponible")

            print(f"Web: {website}")
            print(f"Número de teléfono: {phone_number}")
            print('---')

    else: 
        print(f"NO HAY RESULTADOS PARA {group_name} (Range: {radius} m)")
# Out:
# Latitude: 40.4577291
# Longitude: -3.6758205
#
#  RESULTS FOR PROTECTORAS DE ANIMALES (Range: 5000 m):
#
#
# Nombre: Humane Society Animal and Plant Madrid
# Dirección: C. de Ochagavia, 34, Madrid
# Distancia: 4.0 km
# Actualmente: Abierto
# Horario no disponible
# Web: No disponible
# Número de teléfono: No disponible
# ---
# Nombre: APA Lucha Animal
# Dirección: Madrid
# Distancia: 5.1 km
# Actualmente: Cerrado
# Horario no disponible
# Web: No disponible
# Número de teléfono: No disponible
# ---
# Nombre: Colonia autorizado de gatos
# Dirección: P.º de la Castellana, 75B, Madrid
# Distancia: 2.3 km
# Actualmente: Abierto
# Horario no disponible
# Web: No disponible
# Número de teléfono: No disponible
# ---
# Nombre: Guarida del puma
# Dirección: C. de Prieto Ureña, 3, Madrid
# Distancia: 1.3 km
# Actualmente: Cerrado
# Horario no disponible
# Web: No disponible
# Número de teléfono: No disponible
# ---
# Nombre: Fundación Acuai
# ...

# %%
#Cambios para evitar que el radio seleccionado sea 0.


import googlemaps

# Prompt the user to enter an address
address = input("Enter an address: ")

# Initialize the Google Maps Geocoding client with your API key
gmaps = googlemaps.Client(key='AIzaSyDpY4rSYCn3_B59-hxMT9cesG0O7cSkUnM')

# Use the Geocoding API to retrieve the latitude and longitude of the address
geocode_result = gmaps.geocode(address)

# Extract the latitude and longitude from the geocode result
if geocode_result:
    location = geocode_result[0]['geometry']['location']
    latitude = location['lat']
    longitude = location['lng']
    print(f"Latitude: {latitude}")
    print(f"Longitude: {longitude}")
else:
    print("No se ha podido usar geocode con esta dirección.")

groups = [
    {
        'group_name': 'PROTECTORAS DE ANIMALES',
        'keyword': 'dog shelters, protectoras de perros',
        'radius_prompt' : "Radio de búsqueda en metros para protectoras: "
    },
    {
        'group_name': 'VETERINARIOS',
        'keyword': 'Veterinario',
        'radius_prompt' : "Radio de búsqueda en metros para veterinarios: "
    },
    {
        'group_name': 'TIENDAS DE MASCOTAS',
        'keyword': 'Tiendas de mascotas, pet shop',
        'radius_prompt' : "Radio de búsqueda en metros para tiendas de mascotas: "
    },
    {
        'group_name': 'CRIADORES DE PERROS',
        'keyword': 'Criadores de perros, dog breeders',
        'radius_prompt' : "Radio de búsqueda en metros para criadores: "
    }
]

def get_distance(origin, destination):
    distance = gmaps.distance_matrix(
        origins=origin,
        destinations=destination,
        mode='walking'
    )['rows'][0]['elements'][0]['distance']['text']
    return distance

def find_nearest_shop(latitude, longitude, shops):
    nearest_shop = None
    min_distance = float('inf')

    for shop in shops:
        shop_latitude = shop['geometry']['location']['lat']
        shop_longitude = shop['geometry']['location']['lng']
        distance = get_distance((latitude, longitude), (shop_latitude, shop_longitude))
        if distance < min_distance:
            min_distance = distance
            nearest_shop = shop

    return nearest_shop, min_distance

for group in groups:
    group_name = group['group_name']
    keyword = group['keyword']
    radius_prompt = group['radius_prompt']

    radius = int(input(radius_prompt))

    if radius == 0:
        print("El radio debe ser mayor que cero. No se puede realizar la búsqueda.")
        continue

    # Perform the nearby search for shops
    response = gmaps.places_nearby(
        location=(latitude, longitude),
        radius=radius,
        keyword=keyword
    )

    shops = response['results']

    if not shops:
        print(f"NO HAY RESULTADOS PARA {group_name} (Range: {radius} m)")
        continue

    nearest_shop, min_distance = find_nearest_shop(latitude, longitude, shops)

    print("\n", f"RESULTS FOR {group_name} (Range: {radius} m): ", "\n", "\n")

    name = nearest_shop['name']
    address = nearest_shop['vicinity']
    opening_hours = nearest_shop.get('opening_hours', {})
    is_open_now = opening_hours.get('open_now', False)
    current_opening_hours = opening_hours.get('periods', [])
    website = nearest_shop.get('website', 'No disponible')
    phone_number = nearest_shop.get('formatted_phone_number', 'No disponible')

    print(f"Nombre: {name}")
    print(f"Dirección: {address}")
    if is_open_now:
        print("Actualmente: Abierto")
    else:
        print("Actualmente: Cerrado")

    if current_opening_hours:
        print("Horario:")
        for period in current_opening_hours:
            day = period['open']['day']
            start_time = period['open']['time']
            end_time = period['close']['time']
            day_name = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'][day]
            print(f"Day: {day_name}, Start Time: {start_time}, End Time: {end_time}")
    else:
        print("Horario no disponible")

    print(f"Web: {website}")
    print(f"Número de teléfono: {phone_number}")
    print(f"Distancia: {min_distance}")
    print('---')
# Out:
# Latitude: 40.4656566
# Longitude: -3.6896295
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[173], line 94
#      91     print(f"NO HAY RESULTADOS PARA {group_name} (Range: {radius} m)")
#      92     continue
# ---> 94 nearest_shop, min_distance = find_nearest_shop(latitude, longitude, shops)
#      96 print("\n", f"RESULTS FOR {group_name} (Range: {radius} m): ", "\n", "\n")
#      98 name = nearest_shop['name']
#
# Cell In[173], line 64, in find_nearest_shop(latitude, longitude, shops)
#      62 shop_longitude = shop['geometry']['location']['lng']
#      63 distance = get_distance((latitude, longitude), (shop_latitude, shop_longitude))
# ---> 64 if distance < min_distance:
#      65     min_distance = distance
#      66     nearest_shop = shop
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
# Código para encontrar lo más cercano en general (sigo sin conseguir que me de fuera del rango)

import googlemaps

# Prompt the user to enter an address
address = input("Enter an address: ")

# Initialize the Google Maps Geocoding client with your API key
gmaps = googlemaps.Client(key=YOUR_API_KEY)

# Use the Geocoding API to retrieve the latitude and longitude of the address
geocode_result = gmaps.geocode(address)

# Extract the latitude and longitude from the geocode result
if geocode_result:
    location = geocode_result[0]['geometry']['location']
    latitude = location['lat']
    longitude = location['lng']
    print(f"Latitude: {latitude}")
    print(f"Longitude: {longitude}")
else:
    print("No se ha podido usar geocode con esta dirección.")

groups = [
    {
        'group_name': 'PROTECTORAS DE ANIMALES',
        'keyword': 'dog shelters, protectoras de perros',
        'radius_prompt': "Radio de búsqueda en metros para protectoras: "
    },
    {
        'group_name': 'VETERINARIOS',
        'keyword': 'Veterinario',
        'radius_prompt': "Radio de búsqueda en metros para veterinarios: "
    },
    {
        'group_name': 'TIENDAS DE MASCOTAS',
        'keyword': 'Tiendas de mascotas, pet shop',
        'radius_prompt': "Radio de búsqueda en metros para tiendas de mascotas: "
    },
    {
        'group_name': 'CRIADORES DE PERROS',
        'keyword': 'Criadores de perros, dog breeders',
        'radius_prompt': "Radio de búsqueda en metros para criadores: "
    }
]

def get_distance(origin, destination):
    distance = gmaps.distance_matrix(
        origins=origin,
        destinations=destination,
        mode='walking'
    )['rows'][0]['elements'][0]['distance']['text']
    return distance

def convert_distance_to_numeric(distance):
    numeric_distance = float(distance.split(' ')[0])
    return numeric_distance

def find_nearest_shop(origin, shops):
    nearest_shop = None
    min_distance = float('inf')

    for shop in shops:
        shop_latitude = shop['geometry']['location']['lat']
        shop_longitude = shop['geometry']['location']['lng']
        distance = get_distance(origin, (shop_latitude, shop_longitude))
        numeric_distance = convert_distance_to_numeric(distance)
        if numeric_distance < min_distance:
            min_distance = numeric_distance
            nearest_shop = shop

    return nearest_shop, min_distance

overall_nearest_shop = None
overall_min_distance = float('inf')

for group in groups:
    group_name = group['group_name']
    keyword = group['keyword']
    radius_prompt = group['radius_prompt']

    radius = int(input(radius_prompt))

    if radius == 0:
        print("El radio debe ser mayor que cero. No se puede realizar la búsqueda.")
        continue

    # Perform the nearby search for shops within a wide area
    response = gmaps.places_nearby(
        location=(latitude, longitude),
        radius=500000,  # Set a large radius to retrieve all results in the area
        keyword=keyword
    )

    shops = response['results']

    if not shops:
        print(f"NO HAY RESULTADOS PARA {group_name} (Range: {radius} m)")
        
    else:
        nearest_shop, min_distance = find_nearest_shop((latitude, longitude), shops)
        print("\n", f"RESULTS FOR {group_name} (Range: {radius} m): ", "\n", "\n")
        print(f"Nombre: {nearest_shop['name']}")
        print(f"Dirección: {nearest_shop['vicinity']}")
        print(f"Distancia: {min_distance}")
        print('---')

        if min_distance < overall_min_distance:
            overall_min_distance = min_distance
            overall_nearest_shop = nearest_shop

if overall_nearest_shop:
    print("\n", "Overall Nearest Shop: ", "\n")
    print(f"Nombre: {overall_nearest_shop['name']}")
    print(f"Dirección: {overall_nearest_shop['vicinity']}")
    print(f"Distancia: {overall_min_distance}")
    print('---')
# Out:
# Latitude: 40.4577291
# Longitude: -3.6758205
# NO HAY RESULTADOS PARA PROTECTORAS DE ANIMALES (Range: 2000 m)
#
#  RESULTS FOR VETERINARIOS (Range: 2000 m):
#
#
# Nombre: Clínica Veterinaria Animansión
# Dirección: C. de Molina, 8, Madrid
# Distancia: 2.8
# ---
#
#  RESULTS FOR TIENDAS DE MASCOTAS (Range: 2000 m):
#
#
# Nombre: Interzoo Chamartin
# Dirección: C. de Bolivia, 1, Madrid
# Distancia: 0.4
# ---
#
#  RESULTS FOR CRIADORES DE PERROS (Range: 2000 m):
#
#
# Nombre: Luxury Pets
# Dirección: Calle de Núñez de Balboa, 35A, Madrid
# Distancia: 4.1
# ---
#
#  Overall Nearest Shop:
#
# Nombre: Interzoo Chamartin
# Dirección: C. de Bolivia, 1, Madrid
# Distancia: 0.4
# ---

# %%
#Closest thing I can get to is this. 

import googlemaps

# Prompt the user to enter an address
address = input("Enter an address: ")

# Initialize the Google Maps Geocoding client with your API key
gmaps = googlemaps.Client(key=YOUR_API_KEY)

# Use the Geocoding API to retrieve the latitude and longitude of the address
geocode_result = gmaps.geocode(address)

# Extract the latitude and longitude from the geocode result
if geocode_result:
    location = geocode_result[0]['geometry']['location']
    latitude = location['lat']
    longitude = location['lng']
    print(f"Latitude: {latitude}")
    print(f"Longitude: {longitude}")
else:
    print("No se ha podido usar geocode con esta dirección.")


groups = [
    {
        'group_name': 'PROTECTORAS DE ANIMALES',
        'keyword': 'protectora animales, animal shelter',
        'radius_prompt' : "Radio de búsqueda en metros para protectoras: "
    },
    {
        'group_name': 'VETERINARIOS',
        'keyword': 'Veterinario, Veterinary',
        'radius_prompt' : "Radio de búsqueda en metros para veterinarios: "
    },
    {
        'group_name': 'TIENDAS DE MASCOTAS',
        'keyword': 'Tiendas de mascotas, pet shop, animal shop, tienda de animales',
        'radius_prompt' : "Radio de búsqueda en metros para tiendas de mascotas: "
    },
    {
        'group_name': 'CRIADORES DE PERROS',
        'keyword': 'Criadores, criadores de perros, dog breeders, kennels, cat breeders, criadores de gatos',
        'radius_prompt' : "Radio de búsqueda en metros para criadores: "
    }
]

def get_distance(origin, destination):
    distance = gmaps.distance_matrix(
        origins=origin,
        destinations=destination,
        mode='walking'
    )['rows'][0]['elements'][0]['distance']['text']
    return distance

def convert_distance_to_numeric(distance):
    if isinstance(distance, float):
        return distance
    else:
        numeric_distance = float(distance.split(' ')[0])
        return numeric_distance


def find_nearest_shop(origin, shops):
    nearest_shop = None
    min_distance = float('inf')

    for shop in shops:
        shop_latitude = shop['geometry']['location']['lat']
        shop_longitude = shop['geometry']['location']['lng']
        distance = get_distance(origin, (shop_latitude, shop_longitude))
        numeric_distance = convert_distance_to_numeric(distance)
        if numeric_distance < min_distance:
            min_distance = numeric_distance
            nearest_shop = shop

    return nearest_shop, min_distance

closest_shops = []

for group in groups:
    group_name = group['group_name']
    keyword = group['keyword']
    radius_prompt = f"Radio de búsqueda en metros para {group_name}: "
    
    radius = int(input(radius_prompt))
    
    if radius == 0:
        print(f"El radio debe ser mayor que cero. No se puede realizar la búsqueda para {group_name}.")
        closest_shops.append(None)
        continue
    
    # Perform the nearby search for shops within the specified radius
    response = gmaps.places_nearby(
        location=(latitude, longitude),
        radius=radius,
        keyword=keyword
    )

    shops = response['results']

    if not shops:
        print(f"NO HAY RESULTADOS PARA {group_name} (Range: {radius} m)")
        closest_shops.append(None)
    else:
        print("\n", f"RESULTS FOR {group_name} (Range: {radius} m): ", "\n", "\n")
        for shop in shops:
            print(f"Nombre: {shop['name']}")
            print(f"Dirección: {shop['vicinity']}")
            print('---')

        closest_shop, min_distance = find_nearest_shop((latitude, longitude), shops)
        closest_shops.append({'group_name': group_name, 'shop': closest_shop, 'distance': min_distance})

print("\n", "Closest Shops: ", "\n")

for closest_shop_info in closest_shops:
    group_name = closest_shop_info['group_name']
    closest_shop = closest_shop_info['shop']

    if closest_shop is None:
        print(f"No hay resultados para {group_name} dentro del rango especificado.")
        print(f"No hay resultados para {group_name} dentro del área especificada.")
        print('---')
    else:
        print(f"Nombre: {closest_shop['name']}")
        print(f"Dirección: {closest_shop['vicinity']}")
        print(f"Distancia: {convert_distance_to_numeric(closest_shop_info['distance'])}")
        print('---')
# Out:
# Latitude: 40.4577291
# Longitude: -3.6758205
#
#  RESULTS FOR PROTECTORAS DE ANIMALES (Range: 10000 m):
#
#
# Nombre: Humane Society Animal and Plant Madrid
# Dirección: C. de Ochagavia, 34, Madrid
# ---
# Nombre: APA Lucha Animal
# Dirección: Madrid
# ---
# Nombre: Colonia autorizado de gatos
# Dirección: P.º de la Castellana, 75B, Madrid
# ---
# Nombre: Animal Services Team
# Dirección: C. de Embajadores, 7, Madrid
# ---
# Nombre: Albergue San Francisco de Asis
# Dirección: Madrid
# ---
# Nombre: Guarida del puma
# Dirección: C. de Prieto Ureña, 3, Madrid
# ---
# Nombre: Fundación Acuai
# Dirección: Calle de Castelló, 24, Esc 1, 5º derecha, Madrid
# ---
# Nombre: La Gatoteca
# Dirección: C. del Duque de Rivas, 7, Madrid
# ---
# Nombre: Fundación Iruartiz Lezama
# Dirección: C. Colmenar Viejo, 13, Madrid
# ---
# Nombre: Sociedad Protectora de Animales y Plantas
# Dirección: Carr. de El Pardo a Fuencarral, Madrid
# ---
# Nombre: Arkaanimal
# ...

# %%
#Attempts at getting all the shops within a region.
'''# Define the bounding box coordinates for the region of Madrid
latitude1 = 40.0371  # Southwest corner latitude
longitude1 = -4.576  # Southwest corner longitude
latitude2 = 41.5412  # Northeast corner latitude
longitude2 = -2.232  # Northeast corner longitude

# Perform the places search within the specified bounds
response = gmaps.places(
    query='dog shops',
    bounds=((latitude1, longitude1), (latitude2, longitude2))
)

# Retrieve the places from the response
places = response['results']

# Process the places data
for place in places:
    name = place['name']
    address = place['formatted_address']
    # Extract any other relevant details you need

    print(f"Name: {name}")
    print(f"Address: {address}")
    # Print any other details as needed


# Define the bounding box coordinates for the region of Madrid
latitude1 = 40.0371  # Southwest corner latitude
longitude1 = -4.576  # Southwest corner longitude
latitude2 = 41.5412  # Northeast corner latitude
longitude2 = -2.232  # Northeast corner longitude

# Perform the radar search within the specified bounds
response = gmaps.places_nearby(
    location=(latitude1, longitude1),
    radius=10000,  # Adjust the radius as needed
    keyword='dog shops'
)

# Retrieve the places from the response
places = response['results']

# Process the places data
for place in places:
    name = place['name']
    address = place['formatted_address']
    # Extract any other relevant details you need

    print(f"Name: {name}")
    print(f"Address: {address}")
    # Print any other details as needed






    # Define the bounding box coordinates for the region of Madrid
latitude1 = 40.0371  # Southwest corner latitude
longitude1 = -4.576  # Southwest corner longitude
latitude2 = 41.5412  # Northeast corner latitude
longitude2 = -2.232  # Northeast corner longitude

# Perform the radar search within the specified bounds
response = gmaps.places_nearby(
    location=(latitude1, longitude1),
    radius=10000,  # Adjust the radius as needed
    keyword='Tiendas de animales'
)

# Retrieve the places from the response
places = response['results']

# Process the places data
for place in places:
    name = place['name']
    address = place['vicinity']
    # Extract any other relevant details you need

    print(f"Name: {name}")
    print(f"Address: {address}")
    # Print any other details as needed

'''
